# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafred02/Programacion-I/blob/main/Quiz26/03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quiz 26 Marzo

# %% [markdown]
# Nicolás Mafred Rodriguez Duran 2260676

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("Ingresa el nombre del estudiante: ")

def pedir_nota():
  n1 = float(input("Nota 1: "))
  n2 = float(input("Nota 2: "))
  n3 = float(input("Nota 3: "))
  n4 = float(input("Nota 4: "))
  return n1, n2, n3, n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics

def calcular_promedio(n1, n2, n3, n4):
   return (n1 + n2 + n3 + n4)/4

def mediana(n1, n2, n3, n4):
  return statistics.median([n1, n2, n3, n4])

def moda(n1, n2, n3, n4):
  return statistics.mode([n1, n2, n3, n4])
# Out:
# Overwriting promedio.py

# %%
import pedirnotas
nombre = pedirnotas.pedir_nombre()
n1, n2, n3, n4 = pedirnotas.pedir_nota()
# Out:
# Ingresa el nombre del estudiante: Galindo
# Nota 1: 5.0
# Nota 2: 3.8
# Nota 3: 2.6
# Nota 4: 1.6

# %%
import promedio
import importlib
importlib.reload(promedio)
prom = promedio.calcular_promedio(n1, n2, n3, n4)
med = promedio.mediana(n1, n2, n3, n4)
mod = promedio.moda(n1, n2, n3, n4)

print(f"El estudiante {nombre}: ")

if prom >= 3:
  a = "Aprobado"
  c = "si"
  if prom > 4:
    b = "excelente"
  else:
    b = "bueno"
elif prom < 3:
  a = "Reprobado"
  c = "no"
  if prom < 2:
    b = " muy malo"
  else:
    b = "regular"

print(f"Media aritmetica: En promedio obtuvo {prom} ({a})")
print(f"Mediana: El valor que divide el 50% de las calificaiones es {med}")
print(f"Moda: La calificacion mas repetida es {mod}")
print(f"El desempeño es {b}, ya que {c} logro pasar la materia al optener un promedio de {prom}")
# Out:
# El estudiante Galindo:
# Media aritmetica: En promedio obtuvo 3.25 (Aprobado)
# Mediana: El valor que divide el 50% de las calificaiones es 3.2
# Moda: La calificacion mas repetida es 5.0
# El desempeño es bueno, ya que si logro pasar la materia al optener un promedio de 3.25
