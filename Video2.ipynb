# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafred02/Programacion-I/blob/main/Video2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(0, "->", bool(0))
print(0.0, "->", bool(0.0))
print("", "->", bool(""))
print(list(), "->", bool(list()))
print(tuple(), "->", bool(tuple()))
print(set(), "->", bool(set()))
print(dict(), "->", bool(dict()))
print(None, "->", bool(None))
# Out:
# 0 -> False
# 0.0 -> False
#  -> False
# [] -> False
# () -> False
# set() -> False
# {} -> False
# None -> False

# %%
print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))
print("Cadena", "->", bool("Cadena"))
print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))
print(set((1, 2)), "->", bool(set((1, 2))))
print(dict([(1,2)]), "->", bool(dict([(1,1)])))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# {1: 2} -> True

# %%
nota = float(input("Introduzca su nota: "))
if nota < 5:
  print("Estás suspendido")
else:
  print("Estás aprobado")
# Out:
# Introduzca su nota: 2
# Estás suspendido

# %%
nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Estás suspendido")
elif 5 <= nota and nota < 7:
  print("Aprobado")
elif 7 <= nota and nota < 9:
  print("Notable")
elif 9 <= nota and nota <= 10:
  print("Sobresaliente")
else:
  print("Nota fuera de rango")
# Out:
# Introduzca su nota: 10
# Sobresaliente

# %%
contador = 2
while contador != 0:
  contador = contador - 1
  print("El contenido es", contador)
# Out:
# El contenido es 1
# El contenido es 0

# %%
for i in [1, 2, 3]:
  print(i)
# Out:
# 1
# 2
# 3

# %%
lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for i in diccionario:
  print(i)
# Out:
# 2
# 1
# 0

# %%
lista = list("Hola como estan")

for i in range(len(lista)):
  print("Indice:", i,"Elemento:", lista[i])
# Out:
# Indice: 0 Elemento: H
# Indice: 1 Elemento: o
# Indice: 2 Elemento: l
# Indice: 3 Elemento: a
# Indice: 4 Elemento:
# Indice: 5 Elemento: c
# Indice: 6 Elemento: o
# Indice: 7 Elemento: m
# Indice: 8 Elemento: o
# Indice: 9 Elemento:
# Indice: 10 Elemento: e
# Indice: 11 Elemento: s
# Indice: 12 Elemento: t
# Indice: 13 Elemento: a
# Indice: 14 Elemento: n

# %%
for numero in range(5):
  print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña:Bitboss
# Contraseña incorrecta
# >>> Escriba la contraseña:BitBoss
# ¡Correcta!
