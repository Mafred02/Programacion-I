# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafred02/Programacion-I/blob/main/C2S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#10-17 de marzo 1er Parcial
# p and q -> p y q se cumplen
# p or q -> cualquiera entre las dos se cumple
#not p -> q no se cumple
dia = input("Ingrese el día (L, M, Mi, J, V, S, D): ")

if dia == "S" or dia == "D":
    print("Fin de semana")
elif dia in ["L", "M", "Mi", "J", "V"]:
    print("Entre semana")
else:
    print("Día inválido")
# Out:
# Ingrese el día (L, M, Mi, J, V, S, D): L
# Entre semana

# %%
a = False
b = True
if a ^ b:
  print("XOR verdadero")
else:
  print("XOR falso")
# Out:
# XOR verdadero

# %%
numeros = [3, 7, 12, 9, 5]
for n in numeros:
    if n == 12:
      print("encontrado el numero")
      break
    print(n)
# Out:
# 3
# 7
# encontrado el numero

# %%
n = int(input("Ingrese"))
if n in range(0, 10):
  if n == 1 or n == 0:
    print("El número es ", n)
  else:
    for x in range(2, n):
      if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
    else: # Este else corresponde al for, no al if
      print(n, 'es un número primo')
# Out:
# Ingrese6
# 6 es igual a 2 * 3

# %%
lista = (10, 20, 30, 40, 50)
try:
    index = int(input("Ingresa un índice: "))
    print("El valor es:", lista[index])
except IndexError: # Indice fuera de rango
    print("Índice fuera de rango")
except ValueError: # Cuando ingresamos un valor no permitido
    print("Debes ingresar un número entero")
# Out:
# Ingresa un índice: 0
# El valor es: 10

# %%
clave_correcta = "python123"
intentos = 3
while intentos > 0:
  intento =input("ingresa la contraseña ")
  if intento == clave_correcta:
    print("arcceso concedido")
    break
  else:
    intentos -= 1
    print("intentos restantes:", intentos)
else:
  print("fin de los intentos")
# Out:
# ingresa la contraseña 1
# intentos restantes: 2
# ingresa la contraseña 2
# intentos restantes: 1
# ingresa la contraseña 3
# intentos restantes: 0
# fin de los intentos
